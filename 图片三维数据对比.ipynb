# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bg = plt.imread('bg.jpg')
plt.imshow(bg)

# %%
bg.shape
# Out:
# (116, 260, 3)

# %%
plt.figure(figsize=(1,1))
im = bg[15:55,174:214,:]
plt.imshow(im)

# %%
fullbg = plt.imread('fullbg.jpg')
plt.imshow(fullbg)

# %%
plt.figure(figsize=(1,1))
im2 = fullbg[15:55,174:214,:]
plt.imshow(im2)

# %%
im
# Out:
# array([[[ 62, 157,  89],
#         [  0,  57,   0],
#         [  9,  33,  19],
#         ...,
#         [ 18,  57,  30],
#         [ 13,  60,  28],
#         [  6,  62,  23]],
#
#        [[ 39, 138,  74],
#         [  0,  59,   0],
#         [ 11,  32,  23],
#         ...,
#         [ 23,  68,  35],
#         [ 27,  70,  40],
#         [ 30,  75,  44]],
#
#        [[ 64, 153,  95],
#         [  0,  67,   9],
#         [  7,  27,  18],
#         ...,
#         [ 27,  72,  39],
#         [ 28,  71,  41],
#         [ 27,  74,  42]],
#
#        ...,
#
#        [[255, 255, 244],
#         [220, 220, 208],
#         [236, 238, 227],
#         ...,
#         [254, 239, 232],
#         [250, 246, 235],
#         [237, 248, 231]],
#
#        [[233, 229, 218],
#         [246, 244, 232],
#         [238, 238, 228],
#         ...,
#         [249, 239, 229],
#         [237, 239, 225],
#         [227, 249, 226]],
#
#        [[231, 224, 214],
#         [231, 227, 216],
#         [232, 230, 218],
# ...

# %%
im2
# Out:
# array([[[ 34, 163,  83],
#         [ 28, 157,  77],
#         [ 35, 151,  80],
#         ...,
#         [ 45, 174,  94],
#         [ 45, 174,  94],
#         [ 44, 173,  93]],
#
#        [[ 34, 159,  81],
#         [ 30, 155,  77],
#         [ 47, 138,  81],
#         ...,
#         [ 45, 174,  91],
#         [ 45, 174,  92],
#         [ 47, 176,  94]],
#
#        [[ 47, 163,  90],
#         [ 35, 151,  78],
#         [ 62, 145,  93],
#         ...,
#         [ 41, 170,  88],
#         [ 44, 173,  91],
#         [ 48, 177,  97]],
#
#        ...,
#
#        [[235, 235, 223],
#         [235, 235, 223],
#         [234, 223, 219],
#         ...,
#         [241, 226, 219],
#         [238, 231, 221],
#         [230, 241, 224]],
#
#        [[237, 233, 222],
#         [236, 234, 222],
#         [247, 231, 231],
#         ...,
#         [246, 236, 226],
#         [232, 236, 221],
#         [225, 247, 224]],
#
#        [[239, 232, 222],
#         [237, 233, 222],
#         [243, 224, 226],
# ...

# %%
(im-im2).mean()
# Out:
# 157.06291666666667
